# %% [markdown]
# ## Floor area per dwelling
# Data: Statistikbanken

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import pathlib
from datetime import datetime

from scipy.optimize import curve_fit
import natural_cubic_spline_stack_overflow_kopi as ncs # taken from stack overflow

# %%
floor_area_per_dwelling_data = pd.read_excel("floor_area_pd.xlsx",skiprows=2)

floor_area_per_dwelling_data.head()
# Out:
#   Unnamed: 0  Helårsbeboelse i alt  Stuehus  Parcelhuse  \
# 0       1916                 137.0    227.0       164.0
# 1       1917                 126.0    206.0       155.0
# 2       1918                 112.0    211.0       161.0
# 3       1919                 124.0    227.0       160.0
# 4       1920                 125.0    196.0       151.0
#
#    Række-, kæde- og dobbelthuse  Etageboliger
# 0                         127.0          88.0
# 1                         106.0          87.0
# 2                         113.0          84.0
# 3                         118.0          86.0
# 4                         113.0          89.0
